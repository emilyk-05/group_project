# %% [markdown]
# ## DSCI 100: Group Project

# %% [markdown]
# <h2> Introduction </h2>

# %%
library(tidyverse)
library(janitor)
library(tidymodels)
library(repr)

# %%
players <- read_csv("players.csv") |>
clean_names() 
players

# %% [markdown]
# ## Predictive Question

# %% [markdown]
# <h2>Methods and Results</h2>

# %% [markdown]
# <h2>Discussion</h2>
